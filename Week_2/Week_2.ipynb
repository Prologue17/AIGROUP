# %%
import pandas as pd
import Boston_Week2

# %% [markdown]
# ## ***建立实例对象***

# %%
Boston = Boston_Week2.Linear(Boston_Week2.x, Boston_Week2.y)

# %% [markdown]
# ## ***对特征的标准化***

# %%
pd.DataFrame(Boston.zscore())
# Out:
#       0         1         2         3         4         5         6   \
# 0    1.0 -0.419367  0.284548 -1.286636 -0.272329 -0.144075  0.413263
# 1    1.0 -0.416927 -0.487240 -0.592794 -0.272329 -0.739530  0.194082
# 2    1.0 -0.416929 -0.487240 -0.592794 -0.272329 -0.739530  1.281446
# 3    1.0 -0.416338 -0.487240 -1.305586 -0.272329 -0.834458  1.015298
# 4    1.0 -0.412074 -0.487240 -1.305586 -0.272329 -0.834458  1.227362
# ..   ...       ...       ...       ...       ...       ...       ...
# 501  1.0 -0.412820 -0.487240  0.115624 -0.272329  0.157968  0.438881
# 502  1.0 -0.414839 -0.487240  0.115624 -0.272329  0.157968 -0.234316
# 503  1.0 -0.413038 -0.487240  0.115624 -0.272329  0.157968  0.983986
# 504  1.0 -0.407361 -0.487240  0.115624 -0.272329  0.157968  0.724955
# 505  1.0 -0.414590 -0.487240  0.115624 -0.272329  0.157968 -0.362408
#
#            7         8         9         10        11        12        13
# ...

# %% [markdown]
# ## ***梯度下降法***

# %%
pd.DataFrame(Boston.bgradient_descent())
# Out:
#             0
# 0   22.532806
# 1   -0.929065
# 2    1.082639
# 3    0.141039
# 4    0.682414
# 5   -2.058754
# 6    2.676877
# 7    0.019485
# 8   -3.107116
# 9    2.664852
# 10  -2.078837
# 11  -2.062646
# 12   0.850109
# 13  -3.747332

# %% [markdown]
# ## ***最小二乘法***

# %%
pd.DataFrame(Boston.least_squares())
# Out:
#             0
# 0   36.459488
# 1   -0.108011
# 2    0.046420
# 3    0.020559
# 4    2.686734
# 5  -17.766611
# 6    3.809865
# 7    0.000692
# 8   -1.475567
# 9    0.306049
# 10  -0.012335
# 11  -0.952747
# 12   0.009312
# 13  -0.524758

# %% [markdown]
# ## ***最小二乘法的拟合情况***

# %%
Boston.leastsquares_show()

# %% [markdown]
# ## ***梯度下降法的拟合情况***

# %%
Boston.bgd_show()
